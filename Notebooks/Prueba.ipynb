# %%
from pathlib import Path

for f in Path("../data/gold").glob("*.parquet"):
    print(f)
# Out:
# ..\data\gold\fichas_licitaciones_muestra_10_unificado_v10.parquet

# %%
import pandas as pd

parquet_file = "../data/gold/fichas_licitaciones_muestra_10_unificado_v10.parquet"

df = pd.read_parquet(parquet_file)

print(df.shape)
# Out:
# (10, 58)

# %%
for col in df.columns:
    print(col)
# Out:
# licitacion_id
# portal
# tipo_fuente
# tipo_anuncio
# titulo_original
# titulo_web
# numero_expediente_web
# fecha_publicacion
# fecha_publicacion_texto
# hora_publicacion
# entidad_adjudicadora_web
# organo_contratacion_web
# objeto_contrato_web
# objeto_web
# descripcion_general
# tipo_contrato_web
# tipo_procedimiento_web
# procedimiento_adjudicacion_web
# tipo_tramitacion_web
# sistema_contratacion_web
# metodo_presentacion_ofertas_web
# codigo_cpv_web
# cpv_codes
# cpv_descripciones
# codigo_nuts_web
# lugar_ejecucion
# codigo_subentidad_territorial
# valor_estimado_num
# valor_estimado_contrato_num
# valor_estimado_sin_impuestos_num
# presupuesto_base_num
# presupuesto_base_importe_num
# presupuesto_base_sin_impuestos_num
# presupuesto_base_total_num
# importe_adjudicado_num
# num_lotes_web
# num_lotes_resultado
# fecha_limite_presentacion_web
# duracion_contrato_web
# adjudicatario_web
# resolucion_web
# detail_url
# url_final
# error
# texto_matching
# texto_completo
# ...

# %%
df.head(3).T
# Out:
#                                                                                     0  \
# licitacion_id                                                        4f6977378753d434
# portal                                                                        galicia
# tipo_fuente                                                              html_galicia
# tipo_anuncio                                                                     None
# titulo_original                     Adquisición de diversos artículos, actuaciones...
# titulo_web                                                                       None
# numero_expediente_web                                                            None
# fecha_publicacion                                                                 NaT
# fecha_publicacion_texto                                                          None
# hora_publicacion                                                                 None
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 58 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   licitacion_id                       10 non-null     object
#  1   portal                              10 non-null     object
#  2   tipo_fuente                         10 non-null     object
#  3   tipo_anuncio                        1 non-null      object
#  4   titulo_original                     10 non-null     object
#  5   titulo_web                          6 non-null      object
#  6   numero_expediente_web               7 non-null      object
#  7   fecha_publicacion                   1 non-null      datetime64[us]
#  8   fecha_publicacion_texto             1 non-null      object
#  9   hora_publicacion                    1 non-null      object
#  10  entidad_adjudicadora_web            7 non-null      object
# ...

# %%
(
    df.isnull()
      .sum()
      .sort_values(ascending=False)
      .head(30)
)
# Out:
# descripcion_general                   10
# valor_estimado_num                    10
# error                                 10
# presupuesto_base_total_num            10
# criterios_json                        10
# errores_json                          10
# valor_estimado_sin_impuestos_num      10
# fecha_publicacion                      9
# fecha_publicacion_texto                9
# hora_publicacion                       9
# codigo_subentidad_territorial          9
# presupuesto_base_sin_impuestos_num     9
# tipo_anuncio                           9
# lotes_json                             9
# presupuesto_base_importe_num           9
# num_lotes_resultado                    9
# presupuesto_base_num                   7
# adjudicatario_web                      7
# codigo_nuts_web                        7
# duracion_contrato_web                  7
# importe_adjudicado_num                 7
# tipo_procedimiento_web                 7
# metodo_presentacion_ofertas_web        6
# ...
