# %%
import pandas as pd

# %%
ruta = r"C:\Users\Usuario\TFM\TFM_scraping_contratacion_estado\data\Silver\00_Indice_Licitaciones.xlsx"

# %%
df = pd.read_excel(ruta)

# %%
df.head(10)
# Out:
#    consecutivo   ZIP             Expediente  \
# 0             1  NaN  LICT/99/139/2018/0009
# 1             2  NaN          ASS-0136/2019
# 2             3  NaN  LICT/99/139/2020/0123
# 3             4  NaN           SP00117/2020
# 4             5  NaN          029-2021-0327
# 5             6  NaN  LICT/99/139/2021/0127
# 6             7  NaN           40/VC-270/22
# 7             8  NaN      CS-2022/4002/0004
# 8             9  NaN           SP00254/2021
# 9            10   sí           40/VC-224/23
#
#                                           CPV Código CPV Nombre  \
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN
# 5                                                NaN        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   consecutivo             25 non-null     int64
#  1   ZIP                     14 non-null     object
#  2   Expediente              25 non-null     object
#  3   CPV Código              8 non-null      object
#  4   CPV Nombre              2 non-null      object
#  5   Presentación            25 non-null     object
#  6   Lote                    1 non-null      object
#  7   Descripción             25 non-null     object
#  8   Tipo de contrato        25 non-null     object
#  9   Estado                  25 non-null     object
#  10  Importe                 25 non-null     float64
#  11  Adjudicado              2 non-null      float64
#  12  Órgano de Contratación  25 non-null     object
#  13  Unnamed: 13             1 non-null      object
# ...
